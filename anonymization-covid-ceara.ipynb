# %% [markdown]
# # Anonymization Techniques: Generalization

# %% [markdown]
# ## 1. Goal:
# Implement the generalization technique on a dataset.

# %% [markdown]
# ## 2. Specification:
# Load the “covid.csv” and “regioes.csv” datasets that will be provided to you. The first dataset will already be pseudo-anonymized, while the second will have to be used to generalize an attribute. You must implement a program to perform the generalization of the COVID dataset: </br>
# – Define a generalization tree with 2 levels for the attribute “Municipio” considering the mesoregions of the States of Ceará contained in the dataset “regioes.csv”, and another tree for date of birth with 3 levels: original data (yyyy/mm/ dd), date without day (yyyy/mm), date without day and month (yyyy). Consider level 0, the original data level.</br>
# – From the “covid.csv” dataset and based on the generalization trees sent, the program must perform: </br>
#      1. The full domain generalization of the “Municipio” attribute values to level 1 and recording an anonymized “covid_anon01.csv” file; </br>
#      2. The full domain generalization of the “Nascimento” attribute values to level 1 and write an anonymized “covid_anon02.csv” file. </br>
#      3. Subtree generalization of the “Nascimento” attribute values to level 2 and write an anonymized “covid_anon03.csv” file. To this end, apply anonymization only to records whose individual was born in the 1950s (1950s to 1959). </br>
#      4. The generalization of the full domain of the values of the attributes “Municipio” (level 1) and “Nascimento” (level 2) and recording an anonymized “covid_anon04.csv” file. </br>
# The program should show the two generalization hierarchies defined from the dataset on the screen. </br>
# Program an interface for selecting and viewing the datasets generated for each output, where the user can view the anonymized dataset selected.

# %%
import pandas as pd
import numpy as np
np.warnings.filterwarnings('ignore')

# %% [markdown]
# Dataset "covid.csv"

# %%
df_covid = pd.read_csv('covid.csv', sep=';')

# %%
df_covid.head()
# Out:
#    Unnamed: 0                     Identificador  CodigoMunicipio  Municipio  \
# 0           0  c3ba634113e4b5eb0e3eaae93b09759b         231290.0     SOBRAL
# 1           1  ac84809bfc89b992a0a0221e50b135c0         230960.0    PACAJUS
# 2           2  28ccfaa0c53b792cd1ffa0b7e535f617         230523.0  HORIZONTE
# 3           3  9683fc5fd2c0f7b72fa92ffd259d738a         230440.0  FORTALEZA
# 4           4  e257ccdc48289f02e047cbf046251319         230370.0    CAUCAIA
#
#   Estado     Genero  Nascimento ResultadoExame
# 0     CE  MASCULINO  2003-08-14       Negativo
# 1     CE  MASCULINO  1983-11-07       Negativo
# 2     CE   FEMININO  1982-01-14       Negativo
# 3     CE  MASCULINO  1992-03-12       Negativo
# 4     CE  MASCULINO  1970-03-06       Negativo

# %%
df_covid['CodigoMunicipio'] = df_covid['CodigoMunicipio'].astype('int')

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879543 entries, 0 to 879542
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       879543 non-null  int64
#  1   Identificador    879543 non-null  object
#  2   CodigoMunicipio  879543 non-null  int32
#  3   Municipio        879543 non-null  object
#  4   Estado           879543 non-null  object
#  5   Genero           879543 non-null  object
#  6   Nascimento       879543 non-null  object
#  7   ResultadoExame   879543 non-null  object
# dtypes: int32(1), int64(1), object(6)
# memory usage: 50.3+ MB

# %% [markdown]
# Dataset "regioes.csv"

# %%
df_regiao = pd.read_csv('regioes.csv')

# %%
df_regiao.head()
# Out:
#    Unnamed: 0  Código IBGE do Município Nome da Mesoregião  \
# 0           0                    230010       Sul Cearense
# 1           1                    230015     Norte Cearense
# 2           2                    230020  Noroeste Cearense
# 3           3                    230030  Sertões Cearenses
# 4           4                    230040  Sertões Cearenses
#
#   Sigla da Unidade da Federação Nome das Grandes Regiões
# 0                            CE                 Nordeste
# 1                            CE                 Nordeste
# 2                            CE                 Nordeste
# 3                            CE                 Nordeste
# 4                            CE                 Nordeste

# %%
df_regiao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     184 non-null    int64
#  1   Código IBGE do Município       184 non-null    int64
#  2   Nome da Mesoregião             184 non-null    object
#  3   Sigla da Unidade da Federação  184 non-null    object
#  4   Nome das Grandes Regiões       184 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 7.3+ KB

# %%
# merging datasets on the "Municipio" code. 
df_covid_regiao = pd.merge(df_covid,df_regiao,left_on='CodigoMunicipio',right_on = 'Código IBGE do Município', how = 'inner')

# %%
df_covid_regiao
# Out:
#         Unnamed: 0_x                     Identificador  CodigoMunicipio  \
# 0                  0  c3ba634113e4b5eb0e3eaae93b09759b           231290
# 1                  9  8db897c909c1c246b56ee491e0df994f           231290
# 2                 65  17997c9bd21d9931ea130f1ca65236e9           231290
# 3                 95  25e5850e62482886d70efb3f8438aaa7           231290
# 4                 96  de7400d331c8521d71baa53409d8b4f8           231290
# ...              ...                               ...              ...
# 879538        876429  8ca78bc532162483be4b9ec4c4bc5e64           231123
# 879539        876938  112a5ad7b915503baca248adcd32c6f5           231123
# 879540        877011  4b3a7183752a62c90e2f59cac1d8a984           231123
# 879541        877515  3072ba3050b62e29449eca68420a3983           231123
# 879542        878922  9e3f99aa4a42ed405787b76f72291058           231123
#
#          Municipio Estado     Genero  Nascimento ResultadoExame  Unnamed: 0_y  \
# 0           SOBRAL     CE  MASCULINO  2003-08-14       Negativo           166
# 1           SOBRAL     CE  MASCULINO  1989-12-28       Negativo           166
# 2           SOBRAL     CE   FEMININO  2000-07-08       Negativo           166
# 3           SOBRAL     CE   FEMININO  1954-03-20       Negativo           166
# 4           SOBRAL     CE  MASCULINO  2002-12-06       Negativo           166
# ...            ...    ...        ...         ...            ...           ...
# 879538  POTIRETAMA     CE   FEMININO  1974-09-29       Negativo           146
# 879539  POTIRETAMA     CE  MASCULINO  1941-08-20       Negativo           146
# 879540  POTIRETAMA     CE   FEMININO  1984-02-29       Positivo           146
# 879541  POTIRETAMA     CE   FEMININO  1991-07-04       Positivo           146
# 879542  POTIRETAMA     CE  MASCULINO  1997-01-05       Negativo           146
#
#         Código IBGE do Município Nome da Mesoregião  \
# 0                         231290  Noroeste Cearense
# 1                         231290  Noroeste Cearense
# 2                         231290  Noroeste Cearense
# 3                         231290  Noroeste Cearense
# 4                         231290  Noroeste Cearense
# ...                          ...                ...
# 879538                    231123          Jaguaribe
# 879539                    231123          Jaguaribe
# 879540                    231123          Jaguaribe
# 879541                    231123          Jaguaribe
# 879542                    231123          Jaguaribe
#
#        Sigla da Unidade da Federação Nome das Grandes Regiões
# 0                                 CE                 Nordeste
# 1                                 CE                 Nordeste
# 2                                 CE                 Nordeste
# 3                                 CE                 Nordeste
# 4                                 CE                 Nordeste
# ...                              ...                      ...
# 879538                            CE                 Nordeste
# 879539                            CE                 Nordeste
# 879540                            CE                 Nordeste
# 879541                            CE                 Nordeste
# 879542                            CE                 Nordeste
#
# [879543 rows x 13 columns]

# %%
# Dropping repeated and/or unimportant columns:
df_covid_regiao.drop(columns = ['Unnamed: 0_x', 'Unnamed: 0_y', 'CodigoMunicipio', 'Estado'], inplace = True)

# %%
df_covid_regiao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 879543 entries, 0 to 879542
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Identificador                  879543 non-null  object
#  1   Municipio                      879543 non-null  object
#  2   Genero                         879543 non-null  object
#  3   Nascimento                     879543 non-null  object
#  4   ResultadoExame                 879543 non-null  object
#  5   Código IBGE do Município       879543 non-null  int64
#  6   Nome da Mesoregião             879543 non-null  object
#  7   Sigla da Unidade da Federação  879543 non-null  object
#  8   Nome das Grandes Regiões       879543 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 67.1+ MB

# %% [markdown]
# ### Define a generalization tree with 2 levels for the attribute “Municipio” considering the mesoregions of the States of Ceará contained in the dataset “regioes.csv”, and another tree for date of birth with 3 levels: original data (yyyy/mm/dd ), date without day (yyyy/mm), date without day and month (yyyy). Consider level 0, the original data level.

# %% [markdown]
# **Anonymization for Municipality in 2 levels:**

# %% [markdown]
#                                 Anonymization technique used for Municipality ("Municípios"): Generalization
#
# [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO...]            [ARACATI, SAO JOAO DO JAGUARIBE...]                                [CRATEUS, PIQUET CARNEIRO, TAUA...]
#
#                           Level 1: Generalization for all municipalities according to Mesoregion
#                        |                                          |                                       |
#                        |                                          |                                       |
#                        |                                          |                                       |
#                     [SOBRAL]                               [POTIRETAMA]                               [CRATEUS]
#                                                        Level 0: Municipality ("Município")

# %% [markdown]
# **Anonymization for Data in 3 levels:**

# %% [markdown]
#                                 Anonymization technique used for Data: Generalization
#
#                 [2003]                                     [1989]                                  [2000]
#                                             Level 2: Generalization for year
#                    |                                          |                                       |
#                    |                                          |                                       |
#                    |                                          |                                       |
#                [2003-08]                                  [1989-12]                              [2000-07]
#
#                                           Level 1: Generalization for year and month
#
#                    |                                          |                                       |
#                    |                                          |                                       |
#                    |                                          |                                       |
#              [2003-08-14]                               [1989-12-28]                            [2000-07-08]
#                                                   Level 0: Original date

# %% [markdown]
# **1. The full domain generalization of the “Municipio” attribute values to level 1 and write an anonymized “covid_anon01.csv” file.**

# %%
df_municipio = df_covid_regiao.copy()

# %%
# Number of mesoregions
df_municipio['Nome da Mesoregião'].unique()
# Out:
# array(['Noroeste Cearense', 'Metropolitana de Fortaleza',
#        'Norte Cearense', 'Sul Cearense', 'Jaguaribe', 'Sertões Cearenses',
#        'Centro-Sul Cearense'], dtype=object)

# %%
# List of municipalities according to mesoregion:
list_municipio = df_municipio.groupby('Nome da Mesoregião')['Municipio'].unique()
list_municipio
# Out:
# Nome da Mesoregião
# Centro-Sul Cearense           [IGUATU, OROS, CEDRO, BAIXIO, CARIUS, ICO, LAV...
# Jaguaribe                     [ARACATI, SAO JOAO DO JAGUARIBE, LIMOEIRO DO N...
# Metropolitana de Fortaleza    [PACAJUS, HORIZONTE, FORTALEZA, CAUCAIA, MARAN...
# Noroeste Cearense             [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO, CAMOCI...
# Norte Cearense                [CASCAVEL, SAO GONCALO DO AMARANTE, PARACURU, ...
# Sertões Cearenses             [CRATEUS, PIQUET CARNEIRO, TAUA, ARNEIROZ, QUI...
# Sul Cearense                  [MILAGRES, MISSAO VELHA, CRATO, BREJO SANTO, J...
# Name: Municipio, dtype: object

# %%
dic_municipio = dict(list_municipio)
dic_municipio
# Out:
# {'Centro-Sul Cearense': array(['IGUATU', 'OROS', 'CEDRO', 'BAIXIO', 'CARIUS', 'ICO',
#         'LAVRAS DA MANGABEIRA', 'VARZEA ALEGRE', 'ANTONINA DO NORTE',
#         'JUCAS', 'QUIXELO', 'IPAUMIRIM', 'UMARI', 'TARRAFAS'], dtype=object),
#  'Jaguaribe': array(['ARACATI', 'SAO JOAO DO JAGUARIBE', 'LIMOEIRO DO NORTE', 'RUSSAS',
#         'MORADA NOVA', 'QUIXERE', 'JAGUARIBARA', 'JAGUARIBE', 'IRACEMA',
#         'TABULEIRO DO NORTE', 'PEREIRO', 'ITAICABA', 'ERERE', 'ICAPUI',
#         'JAGUARETAMA', 'IBICUITINGA', 'FORTIM', 'JAGUARUANA', 'ALTO SANTO',
#         'PALHANO', 'POTIRETAMA'], dtype=object),
#  'Metropolitana de Fortaleza': array(['PACAJUS', 'HORIZONTE', 'FORTALEZA', 'CAUCAIA', 'MARANGUAPE',
#         'PACATUBA', 'MARACANAU', 'AQUIRAZ', 'EUSEBIO', 'ITAITINGA',
#         'GUAIÚBA'], dtype=object),
#  'Noroeste Cearense': array(['SOBRAL', 'ACARAU', 'TIANGUA', 'SAO BENEDITO', 'CAMOCIM', 'CRUZ',
#         'HIDROLANDIA', 'SANTA QUITERIA', 'PIRES FERREIRA', 'GRANJA',
#         'ITAREMA', 'CATUNDA', 'IPU', 'RERIUTABA', 'FRECHEIRINHA',
#         'MUCAMBO', 'VICOSA DO CEARA', 'BELA CRUZ', 'IPUEIRAS', 'FORQUILHA',
#         'SANTANA DO ACARAU', 'GRACA', 'MASSAPE', 'CARIRE', 'UBAJARA',
#         'CHAVAL', 'COREAU', 'MARTINOPOLE', 'MARCO', 'BARROQUINHA',
#         'MERUOCA', 'JIJOCA DE JERICOACOARA', 'SENADOR SA', 'MIRAIMA',
#         'GROAIRAS', 'MORRINHOS', 'PACUJA', 'CARNAUBAL', 'VARJOTA',
#         'GUARACIABA DO NORTE', 'IBIAPINA', 'URUOCA', 'ALCANTARAS',
#         'PORANGA', 'MORAUJO', 'CROATA', 'IRAUCUBA'], dtype=object),
#  'Norte Cearense': array(['CASCAVEL', 'SAO GONCALO DO AMARANTE', 'PARACURU', 'ITAPIPOCA',
#         'REDENCAO', 'SAO LUÍS DO CURU', 'BEBERIBE', 'ARATUBA',
#         'URUBURETAMA', 'AMONTADA', 'MULUNGU', 'ARACOIABA', 'CANINDE',
#         'PALMACIA', 'BATURITÉ', 'PINDORETAMA', 'PARAIPABA', 'TRAIRI',
#         'PENTECOSTE', 'BARREIRA', 'ITATIRA', 'CAPISTRANO', 'OCARA',
#         'CHOROZINHO', 'UMIRIM', 'ACARAPE', 'ITAPAJE', 'APUIARES',
#         'CARIDADE', 'TEJUCUOCA', 'TURURU', 'PACOTI', 'ITAPIUNA',
#         'GUARAMIRANGA', 'PARAMOTI', 'GENERAL SAMPAIO'], dtype=object),
#  'Sertões Cearenses': array(['CRATEUS', 'PIQUET CARNEIRO', 'TAUA', 'ARNEIROZ', 'QUIXERAMOBIM',
#         'QUIXADA', 'ACOPIARA', 'BOA VIAGEM', 'MADALENA', 'SABOEIRO',
#         'MOMBACA', 'SENADOR POMPEU', 'PEDRA BRANCA', 'SOLONOPOLE',
#         'NOVA RUSSAS', 'TAMBORIL', 'MONSENHOR TABOSA', 'INDEPENDENCIA',
#         'NOVO ORIENTE', 'MILHA', 'AIUABA', 'IBARETAMA', 'ARARENDA',
#         'QUITERIANOPOLIS', 'CATARINA', 'CHORÓ', 'PARAMBU', 'IPAPORANGA',
#         'DEPUTADO IRAPUAN PINHEIRO', 'BANABUIU'], dtype=object),
#  'Sul Cearense': array(['MILAGRES', 'MISSAO VELHA', 'CRATO', 'BREJO SANTO',
#         'JUAZEIRO DO NORTE', 'BARBALHA', 'ARARIPE', 'CAMPOS SALES',
#         'FARIAS BRITO', 'ALTANEIRA', 'CARIRIACU', 'ABAIARA', 'MAURITI',
#         'AURORA', 'NOVA OLINDA', 'ASSARE', 'SANTANA DO CARIRI', 'JATI',
#         'PORTEIRAS', 'JARDIM', 'GRANJEIRO', 'BARRO', 'POTENGI', 'SALITRE',
#         'PENAFORTE'], dtype=object)}

# %%
# Performing anonymization generalizing the municipality ("município") in question to all municipalities in their respective mesoregion:
df_municipio['Municipio'] = df_municipio['Nome da Mesoregião'].map(dic_municipio)

# %%
df_municipio.sample(5)
# Out:
#                            Identificador  \
# 858733  b41d39d5428c26165b65e10464b8b695
# 112169  17e6e486e111128824e4210e203f8632
# 17789   aeb790983a784aae616d6bf63d9d5849
# 582417  82b4d59cc57dedff45c584a583c97aee
# 128163  9db5524e368268b3cc3dc297b41ec4de
#
#                                                 Municipio     Genero  \
# 858733  [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO, CAMOCI...   FEMININO
# 112169  [PACAJUS, HORIZONTE, FORTALEZA, CAUCAIA, MARAN...   FEMININO
# 17789   [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO, CAMOCI...  MASCULINO
# 582417  [IGUATU, OROS, CEDRO, BAIXIO, CARIUS, ICO, LAV...  MASCULINO
# 128163  [PACAJUS, HORIZONTE, FORTALEZA, CAUCAIA, MARAN...   FEMININO
#
#         Nascimento ResultadoExame  Código IBGE do Município  \
# 858733  1983-03-09       Negativo                    230050
# 112169  1977-08-24       Negativo                    230440
# 17789   1982-04-09       Negativo                    231290
# 582417  1954-09-11       Negativo                    230380
# 128163  1958-12-22       Negativo                    230440
#
#                 Nome da Mesoregião Sigla da Unidade da Federação  \
# 858733           Noroeste Cearense                            CE
# 112169  Metropolitana de Fortaleza                            CE
# 17789            Noroeste Cearense                            CE
# 582417         Centro-Sul Cearense                            CE
# 128163  Metropolitana de Fortaleza                            CE
#
#        Nome das Grandes Regiões
# 858733                 Nordeste
# 112169                 Nordeste
# 17789                  Nordeste
# 582417                 Nordeste
# 128163                 Nordeste

# %% [markdown]
# Considering the total anonymization of the dataset, despite not being expressly requested in the statement, the suppression technique will be applied to the "Código IBGE do Município" field so that the original Municipality is not discovered when being searched for its code.

# %%
# Suppression Technique: IBGE code values will be replaced by "******"
df_municipio.loc[df_municipio['Código IBGE do Município'] > 1, 'Código IBGE do Município'] = '******'

# %%
df_municipio.sample(5)
# Out:
#                            Identificador  \
# 433810  76cd168b8687b9721d87efc44aee8bd9
# 11329   6e8385beccdb0f9fe5157ed948e2f983
# 257539  20afb4980455ec2acc0eef89b7b2ee92
# 489641  63c263f404516799ca2671c9a919ae90
# 659780  7050ac1a85fbeb4026d81c18ea8fb39a
#
#                                                 Municipio     Genero  \
# 433810  [PACAJUS, HORIZONTE, FORTALEZA, CAUCAIA, MARAN...   FEMININO
# 11329   [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO, CAMOCI...   FEMININO
# 257539  [PACAJUS, HORIZONTE, FORTALEZA, CAUCAIA, MARAN...   FEMININO
# 489641  [CASCAVEL, SAO GONCALO DO AMARANTE, PARACURU, ...  MASCULINO
# 659780  [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO, CAMOCI...  MASCULINO
#
#         Nascimento ResultadoExame Código IBGE do Município  \
# 433810  1980-12-16       Provável                   ******
# 11329   1989-01-09       Negativo                   ******
# 257539  1971-07-18       Negativo                   ******
# 489641  1985-01-11       Negativo                   ******
# 659780  1981-03-30       Negativo                   ******
#
#                 Nome da Mesoregião Sigla da Unidade da Federação  \
# 433810  Metropolitana de Fortaleza                            CE
# 11329            Noroeste Cearense                            CE
# 257539  Metropolitana de Fortaleza                            CE
# 489641              Norte Cearense                            CE
# 659780           Noroeste Cearense                            CE
#
#        Nome das Grandes Regiões
# 433810                 Nordeste
# 11329                  Nordeste
# 257539                 Nordeste
# 489641                 Nordeste
# 659780                 Nordeste

# %%
# Converting the dataframe to an anonymized file:
df_municipio.to_csv('covid_anon01.csv', index = False)

# %% [markdown]
# **2. The full domain generalization of the “Birth” attribute values to level 1 and writing an anonymized “covid_anon02.csv” file.**

# %%
df_nascimento = df_covid.copy()

# %%
df_nascimento.drop(columns = ['Unnamed: 0'], inplace = True)

# %% [markdown]
# When inspecting the dataset, it is possible to observe that there are dates below 1900. Therefore, the first step will be to change the values of these dates, so that any date between 1600-1899 becomes a value within the 20th century.

# %%
# Dates of birth with values between 1600-1899.
df_nascimento[df_nascimento['Nascimento'].str.contains('^16|^17|^18')]
# Out:
#                            Identificador  CodigoMunicipio  \
# 31516   cef7b4f3742dbd0590ac4f803f82b9f7           230300
# 34517   81477c7bf949f9108ea4e7baa986460e           230340
# 37156   538ff42c112efcf5db644fbd12155426           231140
# 40178   4a3f2df72236698b9db233294c9aa55d           230470
# 40179   badbbdfd53b5de472963375134af27d8           230426
# 40181   98ef3813ede57b158ed15027e61749b1           230533
# 40191   e3ff9650bc38b225d2b8813c642ea251           230550
# 40193   31f5c8867ab60523a6d3f80b1ca398bc           230580
# 40196   6dbdcf86a1374024010d7c98d05a1d1d           230550
# 40200   f6a1d946e6c12774aff3977beb4885ce           230630
# 840929            VICOSA DO CEARA     CE   FEMININO  1695-09-16       Negativo
# 841184                  MARACANAU     CE   FEMININO  1899-12-30       Negativo
# 850168                  ITAITINGA     CE   FEMININO  1691-02-27       Negativo
# 868904                  FORTALEZA     CE  MASCULINO  1669-02-06       Provável

# %%
# Replacing the values 16, 17 and 18 with 19, so that the base only has dates of birth from 1900 onwards
index = df_nascimento[df_nascimento['Nascimento'].str.contains('^16|^17|^18')].index
df_nascimento.loc[index, 'Nascimento'] = df_nascimento.loc[index,'Nascimento'].str.replace('^16|^17|^18','19')

# %%
# Example of a value that previously had a date: 1894-03-16
df_nascimento.loc[df_nascimento['Identificador']=='a4e89b7dfa149cac27b5b524eae59ca1']
# Out:
#                           Identificador  CodigoMunicipio      Municipio  \
# 64694  a4e89b7dfa149cac27b5b524eae59ca1           231400  VARZEA ALEGRE
#
#       Estado     Genero  Nascimento ResultadoExame
# 64694     CE  MASCULINO  1994-03-16       Positivo

# %% [markdown]
# After the transformation of the initial data, the dataset will be copied so that levels 1 and 2 can work on for anonymization.

# %%
df_nascimento_1 = df_nascimento.copy()

# %%
df_nascimento_1['Nascimento'] = pd.to_datetime(df_nascimento['Nascimento'])

# %%
# Creating Level 1: Year and Month
df_nascimento_1['Nascimento'] = df_nascimento_1['Nascimento'].map(lambda x: x.strftime("%Y-%m"))

# %%
# Random samples from the anonymized dataset for the first level of the "Nascimento" attribute:
df_nascimento_1.sample(5)
# Out:
#                            Identificador  CodigoMunicipio          Municipio  \
# 452014  33f4dc8eff891f390ff7f34016151b37           230250        BREJO SANTO
# 502908  24136f58e355feadf5ee328d682bf78e           230880            MORAUJO
# 867505  005136abc424901dcefc1e17a3d7de7d           231025          PARAIPABA
# 134174  592d29e87617e6935b181d1d90aee2a1           230540                ICO
# 801425  ebc963748dcdd38a55f84d8dcd7bff7c           230730  JUAZEIRO DO NORTE
#
#        Estado     Genero Nascimento ResultadoExame
# 452014     CE   FEMININO    1992-08       Negativo
# 502908     CE  MASCULINO    1987-02       Negativo
# 867505     CE   FEMININO    1999-10       Provável
# 134174     CE   FEMININO    2012-01       Negativo
# 801425     CE  MASCULINO    1990-04       Positivo

# %%
df_nascimento_1.to_csv('covid_anon02.csv', index = False)

# %% [markdown]
# **3. Subtree generalization of the Nascimento attribute values to level 2 and write an anonymized “covid_anon03.csv” file. Apply anonymization only to records whose individual was born in the 1950s (1950s to 1959).**

# %% [markdown]
# As the statement informs, the anonymization should be done only in individuals born in the 1950s. The others will not be anonymized. Therefore, for the birth ("Nascimento") attribute, the data will be at level 0 (outside the range) and level 2 (range).

# %%
df_nascimento_2 = df_nascimento.copy()

# %%
# Creating Level 2: Year
df_nascimento_2['Ano'] = pd.DatetimeIndex(df_nascimento_2['Nascimento']).year

# %%
df_nascimento_2['Ano'] = df_nascimento_2['Ano'].astype('int')

# %%
df_nascimento_2
# Out:
#                            Identificador  CodigoMunicipio          Municipio  \
# 0       c3ba634113e4b5eb0e3eaae93b09759b           231290             SOBRAL
# 1       ac84809bfc89b992a0a0221e50b135c0           230960            PACAJUS
# 2       28ccfaa0c53b792cd1ffa0b7e535f617           230523          HORIZONTE
# 3       9683fc5fd2c0f7b72fa92ffd259d738a           230440          FORTALEZA
# 4       e257ccdc48289f02e047cbf046251319           230370            CAUCAIA
# ...                                  ...              ...                ...
# 879538  034184a3bba5a9d9020c6f78287cfb30           230440          FORTALEZA
# 879539  7f4c28d219dd03de2457b16de64563a0           230440          FORTALEZA
# 879540  4f8257be1fefe7e9a3b17f08247792c6           230440          FORTALEZA
# 879541  2b610df8ede251af2e17a6ac07726678           230410            CRATEUS
# 879542  d4ba826d7f018ef730718faf76668d73           230730  JUAZEIRO DO NORTE
#
#        Estado     Genero  Nascimento ResultadoExame   Ano
# 0          CE  MASCULINO  2003-08-14       Negativo  2003
# 1          CE  MASCULINO  1983-11-07       Negativo  1983
# 2          CE   FEMININO  1982-01-14       Negativo  1982
# 3          CE  MASCULINO  1992-03-12       Negativo  1992
# 4          CE  MASCULINO  1970-03-06       Negativo  1970
# ...       ...        ...         ...            ...   ...
# 879538     CE   FEMININO  1982-12-08       Positivo  1982
# 879539     CE   FEMININO  1980-12-02       Negativo  1980
# 879540     CE   FEMININO  1988-05-17       Provável  1988
# 879541     CE   FEMININO  1970-09-28       Negativo  1970
# 879542     CE   FEMININO  1998-12-14       Positivo  1998
#
# [879543 rows x 8 columns]

# %%
intervalo = df_nascimento_2[['Nascimento','Ano']].loc[(df_nascimento_2['Ano']>=1950) & (df_nascimento_2['Ano']<=1959)] 
intervalo
# Out:
#         Nascimento   Ano
# 26      1951-04-12  1951
# 36      1950-02-03  1950
# 39      1953-08-03  1953
# 64      1952-01-17  1952
# 88      1958-12-23  1958
# ...            ...   ...
# 879519  1951-01-04  1951
# 879527  1956-09-09  1956
# 879528  1954-12-18  1954
# 879535  1956-10-21  1956
# 879536  1957-06-02  1957
#
# [63475 rows x 2 columns]

# %%
residual = df_nascimento_2[['Nascimento','Ano']].loc[(df_nascimento_2['Ano']<1950) | (df_nascimento_2['Ano']>1959)]
residual['Ano']=residual['Nascimento']
residual
# Out:
#         Nascimento         Ano
# 0       2003-08-14  2003-08-14
# 1       1983-11-07  1983-11-07
# 2       1982-01-14  1982-01-14
# 3       1992-03-12  1992-03-12
# 4       1970-03-06  1970-03-06
# ...            ...         ...
# 879538  1982-12-08  1982-12-08
# 879539  1980-12-02  1980-12-02
# 879540  1988-05-17  1988-05-17
# 879541  1970-09-28  1970-09-28
# 879542  1998-12-14  1998-12-14
#
# [816068 rows x 2 columns]

# %%
# Merge to form a dictionary covering all lines totaling 879543 lines like the original:
df_dic = pd.concat([intervalo,residual])
df_dic
# Out:
#         Nascimento         Ano
# 26      1951-04-12        1951
# 36      1950-02-03        1950
# 39      1953-08-03        1953
# 64      1952-01-17        1952
# 88      1958-12-23        1958
# ...            ...         ...
# 879538  1982-12-08  1982-12-08
# 879539  1980-12-02  1980-12-02
# 879540  1988-05-17  1988-05-17
# 879541  1970-09-28  1970-09-28
# 879542  1998-12-14  1998-12-14
#
# [879543 rows x 2 columns]

# %%
#  '1955-07-31': 1955,
#  '1958-10-26': 1958,
#  '1955-11-26': 1955,
#  '1959-12-31': 1959,
#  '1955-10-20': 1955,
#  '1950-04-11': 1950,
#  '1950-07-31': 1950,
#  '1955-03-09': 1955,
#  '1958-02-15': 1958,
#  '1955-01-30': 1955,
#  '1959-07-05': 1959,
#  '1956-02-09': 1956,
#  '1959-05-22': 1959,
#  '1957-01-11': 1957,
#  '1953-06-23': 1953,
#  '1957-05-16': 1957,
#  '1957-12-12': 1957,
#  '1950-03-14': 1950,
#  '1954-06-27': 1954,
#  '1955-03-19': 1955,
#  '1951-04-28': 1951,
#  '1959-04-06': 1959,
#  '1958-02-08': 1958,
#  '1958-09-04': 1958,
#  '1957-03-17': 1957,
#  '1955-12-02': 1955,
#  '1955-05-22': 1955,
#  '1956-12-24': 1956,
#  '1952-07-03': 1952,
#  '1952-01-16': 1952,
#  '1959-12-13': 1959,
#  '1956-09-08': 1956,
#  '1957-01-18': 1957,
#  '1953-07-06': 1953,
#  '1951-05-05': 1951,
#  '1956-01-05': 1956,
#  '1954-12-25': 1954,
#  '1956-07-25': 1956,
#  '1957-10-29': 1957,
#  '1955-03-17': 1955,
#  '1957-06-21': 1957,
#  '1957-02-27': 1957,
#  '1950-03-29': 1950,
#  '1959-11-11': 1959,
#  '1957-02-26': 1957,
#  '1954-02-05': 1954,
#  '1952-09-05': 1952,
#  '1951-01-18': 1951,
#  '1956-05-31': 1956,
#  '1951-05-20': 1951,
#  '1957-09-08': 1957,
#  '1952-03-25': 1952,
#  '1950-02-20': 1950,
#  '1952-08-21': 1952,
#  '1951-06-29': 1951,
#  '1954-01-14': 1954,
#  '1950-06-13': 1950,
#  '1952-06-18': 1952,
#  '1951-10-18': 1951,
#  '1954-07-03': 1954,
#  '1955-07-03': 1955,
#  '1955-02-04': 1955,
#  '1954-12-06': 1954,
#  '1958-11-13': 1958,
#  '1957-06-12': 1957,
#  '1955-05-24': 1955,
#  '1954-07-18': 1954,
#  '1955-07-27': 1955,
#  '1958-08-16': 1958,
#  '1953-02-18': 1953,
#  '1953-03-14': 1953,
#  '1956-11-07': 1956,
#  '1957-08-14': 1957,
#  '1958-08-26': 1958,
#  '1955-03-11': 1955,
#  '1956-09-27': 1956,
#  ...}

# %%
# Replacing only the values that belong to the range: 1950-1959
df_nascimento_2['Nascimento'] = df_nascimento_2['Nascimento'].map(dic_ano)

# %%
df_nascimento_2.drop(columns = ['Ano'], inplace = True)

# %%
df_nascimento_2.sample(10)
# Out:
#                            Identificador  CodigoMunicipio     Municipio  \
# 430612  9c9bf7cfbed16ed820f34daa7fb840e7           230440     FORTALEZA
# 700623  d20204b2d01db43b1ef6e66145f726c4           231150       QUIXERE
# 524130  60527a799878b0fec4bb9a7f8ca75944           231290        SOBRAL
# 186667  62a90e916893bdb218ce2fed7a7b8f90           230765     MARACANAU
# 170210  9715b4562db9395974adf0dba70795c1           230190      BARBALHA
# 102274  eea32868e19c59623edbca9b832303c3           231340       TIANGUA
# 677291  d26d5d0c426fba4ad13cf8b9eed19cd5           231140  QUIXERAMOBIM
# 203160  a687e8756a9c7775db0eb394b6903c2d           230490      GROAIRAS
# 533774  60a30c5a1df698198476db4d119a2b7f           231180        RUSSAS
# 635281  215f31142d8facc65a42e3d3401fd9fa           231320      TAMBORIL
#
#        Estado     Genero  Nascimento ResultadoExame
# 430612     CE  MASCULINO  1997-10-19       Negativo
# 700623     CE   FEMININO  1987-04-01       Negativo
# 524130     CE   FEMININO  1991-12-25       Positivo
# 186667     CE  MASCULINO        1953       Provável
# 170210     CE   FEMININO  1985-11-16       Negativo
# 102274     CE  MASCULINO  1980-10-22       Negativo
# 677291     CE   FEMININO  1979-06-11       Positivo
# 203160     CE  MASCULINO  1995-08-25       Negativo
# 533774     CE  MASCULINO  1941-01-05       Negativo
# 635281     CE  MASCULINO  1966-09-12       Positivo

# %%
# Converting the dataframe to an anonymized file:
df_nascimento_2.to_csv('covid_anon03.csv', index = False)

# %% [markdown]
# **4. Full domain generalization of the values of the “Municipio” (level 1) and "Nascimento" (level 2) attributes and recording an anonymized “covid_anon04.csv” file.**

# %% [markdown]
# The dataframe formed by the dataset of the region and covid will be used after the anonymization of the Municipality: df_municipio

# %%
df_municipio_nascimento = df_municipio.copy()
df_municipio_nascimento
# Out:
#                            Identificador  \
# 0       c3ba634113e4b5eb0e3eaae93b09759b
# 1       8db897c909c1c246b56ee491e0df994f
# 2       17997c9bd21d9931ea130f1ca65236e9
# 3       25e5850e62482886d70efb3f8438aaa7
# 4       de7400d331c8521d71baa53409d8b4f8
# ...                                  ...
# 879538  8ca78bc532162483be4b9ec4c4bc5e64
# 879539  112a5ad7b915503baca248adcd32c6f5
# 879540  4b3a7183752a62c90e2f59cac1d8a984
# 879541  3072ba3050b62e29449eca68420a3983
# 879542  9e3f99aa4a42ed405787b76f72291058
#
#                                                 Municipio     Genero  \
# 0       [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO, CAMOCI...  MASCULINO
# 1       [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO, CAMOCI...  MASCULINO
# 2       [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO, CAMOCI...   FEMININO
# 3       [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO, CAMOCI...   FEMININO
# 4       [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO, CAMOCI...  MASCULINO
# ...                                                   ...        ...
# 879538  [ARACATI, SAO JOAO DO JAGUARIBE, LIMOEIRO DO N...   FEMININO
# 879539  [ARACATI, SAO JOAO DO JAGUARIBE, LIMOEIRO DO N...  MASCULINO
# 879540  [ARACATI, SAO JOAO DO JAGUARIBE, LIMOEIRO DO N...   FEMININO
# 879541  [ARACATI, SAO JOAO DO JAGUARIBE, LIMOEIRO DO N...   FEMININO
# 879542  [ARACATI, SAO JOAO DO JAGUARIBE, LIMOEIRO DO N...  MASCULINO
#
#         Nascimento ResultadoExame Código IBGE do Município Nome da Mesoregião  \
# 0       2003-08-14       Negativo                   ******  Noroeste Cearense
# 1       1989-12-28       Negativo                   ******  Noroeste Cearense
# 2       2000-07-08       Negativo                   ******  Noroeste Cearense
# 3       1954-03-20       Negativo                   ******  Noroeste Cearense
# 4       2002-12-06       Negativo                   ******  Noroeste Cearense
# ...            ...            ...                      ...                ...
# 879538  1974-09-29       Negativo                   ******          Jaguaribe
# 879539  1941-08-20       Negativo                   ******          Jaguaribe
# 879540  1984-02-29       Positivo                   ******          Jaguaribe
# 879541  1991-07-04       Positivo                   ******          Jaguaribe
# 879542  1997-01-05       Negativo                   ******          Jaguaribe
#
#        Sigla da Unidade da Federação Nome das Grandes Regiões
# 0                                 CE                 Nordeste
# 1                                 CE                 Nordeste
# 2                                 CE                 Nordeste
# 3                                 CE                 Nordeste
# 4                                 CE                 Nordeste
# ...                              ...                      ...
# 879538                            CE                 Nordeste
# 879539                            CE                 Nordeste
# 879540                            CE                 Nordeste
# 879541                            CE                 Nordeste
# 879542                            CE                 Nordeste
#
# [879543 rows x 9 columns]

# %%
df_municipio_nascimento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 879543 entries, 0 to 879542
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Identificador                  879543 non-null  object
#  1   Municipio                      879543 non-null  object
#  2   Genero                         879543 non-null  object
#  3   Nascimento                     879543 non-null  object
#  4   ResultadoExame                 879543 non-null  object
#  5   Código IBGE do Município       879543 non-null  object
#  6   Nome da Mesoregião             879543 non-null  object
#  7   Sigla da Unidade da Federação  879543 non-null  object
#  8   Nome das Grandes Regiões       879543 non-null  object
# dtypes: object(9)
# memory usage: 67.1+ MB

# %%
# Replacing only the values that belong to the range: 1950-1959
df_municipio_nascimento['Nascimento'] = df_municipio_nascimento['Nascimento'].map(dic_ano)

# %%
df_municipio_nascimento
# Out:
#                            Identificador  \
# 0       c3ba634113e4b5eb0e3eaae93b09759b
# 1       8db897c909c1c246b56ee491e0df994f
# 2       17997c9bd21d9931ea130f1ca65236e9
# 3       25e5850e62482886d70efb3f8438aaa7
# 4       de7400d331c8521d71baa53409d8b4f8
# ...                                  ...
# 879538  8ca78bc532162483be4b9ec4c4bc5e64
# 879539  112a5ad7b915503baca248adcd32c6f5
# 879540  4b3a7183752a62c90e2f59cac1d8a984
# 879541  3072ba3050b62e29449eca68420a3983
# 879542  9e3f99aa4a42ed405787b76f72291058
#
#                                                 Municipio     Genero  \
# 0       [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO, CAMOCI...  MASCULINO
# 1       [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO, CAMOCI...  MASCULINO
# 2       [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO, CAMOCI...   FEMININO
# 3       [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO, CAMOCI...   FEMININO
# 4       [SOBRAL, ACARAU, TIANGUA, SAO BENEDITO, CAMOCI...  MASCULINO
# ...                                                   ...        ...
# 879538  [ARACATI, SAO JOAO DO JAGUARIBE, LIMOEIRO DO N...   FEMININO
# 879539  [ARACATI, SAO JOAO DO JAGUARIBE, LIMOEIRO DO N...  MASCULINO
# 879540  [ARACATI, SAO JOAO DO JAGUARIBE, LIMOEIRO DO N...   FEMININO
# 879541  [ARACATI, SAO JOAO DO JAGUARIBE, LIMOEIRO DO N...   FEMININO
# 879542  [ARACATI, SAO JOAO DO JAGUARIBE, LIMOEIRO DO N...  MASCULINO
#
#         Nascimento ResultadoExame Código IBGE do Município Nome da Mesoregião  \
# 0       2003-08-14       Negativo                   ******  Noroeste Cearense
# 1       1989-12-28       Negativo                   ******  Noroeste Cearense
# 2       2000-07-08       Negativo                   ******  Noroeste Cearense
# 3             1954       Negativo                   ******  Noroeste Cearense
# 4       2002-12-06       Negativo                   ******  Noroeste Cearense
# ...            ...            ...                      ...                ...
# 879538  1974-09-29       Negativo                   ******          Jaguaribe
# 879539  1941-08-20       Negativo                   ******          Jaguaribe
# 879540  1984-02-29       Positivo                   ******          Jaguaribe
# 879541  1991-07-04       Positivo                   ******          Jaguaribe
# 879542  1997-01-05       Negativo                   ******          Jaguaribe
#
#        Sigla da Unidade da Federação Nome das Grandes Regiões
# 0                                 CE                 Nordeste
# 1                                 CE                 Nordeste
# 2                                 CE                 Nordeste
# 3                                 CE                 Nordeste
# 4                                 CE                 Nordeste
# ...                              ...                      ...
# 879538                            CE                 Nordeste
# 879539                            CE                 Nordeste
# 879540                            CE                 Nordeste
# 879541                            CE                 Nordeste
# 879542                            CE                 Nordeste
#
# [879543 rows x 9 columns]

# %%
df_municipio_nascimento.to_csv('covid_anon04.csv', index = False)

# %% [markdown]
# # Interface

# %% [markdown]
# The interface contains four buttons referring to different types of anonymization that have been worked on throughout this notebook. This way, the user will be able to choose the type of anonymization and the dataset he wants to see.

# %%
import pandas as pd
from tkinter import *
from pandastable import Table, TableModel

class MyApp():
    def __init__(self, master):
        self.master = master
        master.title("Anonymized Datasets")
        master.configure(bg='#4169e1')

        
        self.button_1 = Button(master,text="Anonymization 1: Municipality ('Município') - level 1",font= ('Helvetica 16'), fg=("black"), 
                               command=self.display_df_in_new_window_1) 
        self.button_1.grid(column=0, row=0, padx=20, pady=20)
        self.button_1.configure(bg='white')
        
        self.button_2 = Button(master,text="Anonymization 2: Birth ('Nascimento') - level 1",font= ('Helvetica 16'), fg=("black"),
                               command=self.display_df_in_new_window_2) 
        self.button_2.grid(column=0, row=1, padx=20, pady=20)
        self.button_2.configure(bg='white')
        
        self.button_3 = Button(master,text="Anonymization 3: Birth ('Nascimento') - level 2", font= ('Helvetica 16'), fg=("black"),
                               command=self.display_df_in_new_window_3) 
        self.button_3.grid(column=0, row=2, padx=20, pady=20)
        self.button_3.configure(bg='white')
        
        self.button_4 = Button(master,text="Anonymization 4: Municipality ('Município') (1) and Birth ('Nascimento') (2)",font= ('Helvetica 16'), fg=("black"),
                               command=self.display_df_in_new_window_4) 
        self.button_4.grid(column=0, row=3, padx=20, pady=20)
        self.button_4.configure(bg='white')

    def display_df_in_new_window_1(self):
       frame = Toplevel(self.master) #this is the new window
       self.table = Table(frame, dataframe=pd.read_csv('covid_anon01.csv'), showtoolbar=True, showstatusbar=True)
       self.table.show()
    def display_df_in_new_window_2(self):
       frame = Toplevel(self.master) #this is the new window
       self.table = Table(frame, dataframe=pd.read_csv('covid_anon02.csv'), showtoolbar=True, showstatusbar=True)
       self.table.show()
    def display_df_in_new_window_3(self):
       frame = Toplevel(self.master) #this is the new window
       self.table = Table(frame, dataframe=pd.read_csv('covid_anon03.csv'), showtoolbar=True, showstatusbar=True)
       self.table.show()
    def display_df_in_new_window_4(self):
       frame = Toplevel(self.master) #this is the new window
       self.table = Table(frame, dataframe=pd.read_csv('covid_anon04.csv'), showtoolbar=True, showstatusbar=True)
       self.table.show()
    

root = Tk()
my_gui = MyApp(root)
root.mainloop()
